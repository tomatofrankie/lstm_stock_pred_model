# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import LSTM, Dense, Bidirectional
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
import yfinance as yf
import tensorflow as tf
from pandas_datareader.yahoo.daily import YahooDailyReader
from stockstats import StockDataFrame
from datetime import datetime
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler


# Define the list of stock tickers and the date range
stock_tickers = ['OXY']#, 'GOOGL', 'MSFT']  # Replace with your list of stock tickers
start_date = '1994-01-01'  # Replace with your desired start date
end_date = '2023-09-17'  # Replace with your desired end date
# end_date = datetime.today()


def create_time_steps(length):
    return list(range(-length, 0))

def multi_step_plot(history, true_future, prediction):
    plt.figure(figsize=(18, 6))
    num_in = create_time_steps(len(history))
    num_out = len(true_future)

    plt.plot(num_in, np.array(history[:, 0]), label='History')
    plt.plot(np.arange(num_out)/STEP, np.array(true_future), 'bo',
        label='True Future')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, np.array(prediction), 'ro',
                 label='Predicted Future')
    plt.legend(loc='upper left')
    plt.show()

def multivariate_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []

    start_index = start_index + history_size
    if end_index is None:
        end_index = len(dataset) - target_size

    for i in range(start_index, end_index):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

        if single_step:
            labels.append(target[i+target_size])
        else:
            labels.append(target[i:i+target_size])

    return np.array(data), np.array(labels)

def plot_train_history(history, title):
    loss = history.history['loss']
    val_loss = history.history['val_loss']

    epochs = range(len(loss))

    plt.figure()

    plt.plot(epochs, loss, 'b', label='Training loss')
    plt.plot(epochs, val_loss, 'r', label='Validation loss')
    plt.title(title)
    plt.legend()

    plt.show()

def multinew_data(dataset, target, start_index, end_index, history_size,
                      target_size, step, single_step=False):
    data = []
    labels = []   

    # start_index = start_index + history_size
    start_index = -history_size
    if end_index is None:
        end_index = len(dataset) 

    for i in range(start_index, end_index-target_size):
        indices = range(i-history_size, i, step)
        data.append(dataset[indices])

    return np.array(data)

def prediction_plot(history, prediction):
    plt.figure(figsize=(18, 6))
    num_in = create_time_steps(len(history))
    num_out = len(prediction[0])

    plt.plot(num_in, np.array(history), label='History')
    if prediction.any():
        plt.plot(np.arange(num_out)/STEP, np.array(prediction)[0], 'ro',
                 label='Predicted Future')
    plt.legend(loc='upper left')
    plt.show()

# %%
# # Loop over each stock ticker
# # for ticker in stock_tickers:
# # Download stock price data using yfinance

# %%
ticker = stock_tickers[0]

df = yf.download(ticker, start=start_date, end=end_date, auto_adjust=False)
df = StockDataFrame.retype(df)
TRAIN_SPLIT = int(df.shape[0] * 0.8)
# df.head()

features_considered = ['close','macds','macd']
features = df[features_considered]
features.index = df.index
features.head()

features.plot(subplots=True,figsize=[12,10])
# Out:
# [*********************100%%**********************]  1 of 1 completed
# array([<Axes: xlabel='Date'>, <Axes: xlabel='Date'>,
#        <Axes: xlabel='Date'>], dtype=object)

# %%
# Assuming your dataframe is called 'df' with columns 'column1', 'column2', 'column3'
columns_to_normalize = ['close', 'macds', 'macd']

# # Create an instance of MinMaxScaler
# scaler = MinMaxScaler()

# # Fit the scaler on the selected columns
# scaler.fit(features[columns_to_normalize])

# # Transform the selected columns using the scaler
# features[columns_to_normalize] = scaler.transform(features[columns_to_normalize])

# dataset = features.values


dataset = features.values
data_mean = dataset[:TRAIN_SPLIT].mean(axis=0)
data_std = dataset[:TRAIN_SPLIT].std(axis=0)
dataset = (dataset-data_mean)/data_std


pd.DataFrame(dataset, columns = features.columns, index = features.index).head()
# Out:
#                close     macds      macd
# Date
# 1994-01-03 -1.113246 -0.068929 -0.064807
# 1994-01-04 -1.115139 -0.069763 -0.066205
# 1994-01-05 -1.109459 -0.067653 -0.060793
# 1994-01-06 -1.105673 -0.064128 -0.053933
# 1994-01-07 -1.105673 -0.060962 -0.050434

# %%
past_history = 20
future_target = 5
STEP = 1

# Hyperparameters
BATCH_SIZE = 32
BUFFER_SIZE = 2000



x_train_multi, y_train_multi = multivariate_data(dataset, dataset[:, 0], 0,
                                                 TRAIN_SPLIT, past_history,
                                                 future_target, STEP)
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 0],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)



# train_data_multi = tf.data.Dataset.from_tensor_slices((x_train_multi, y_train_multi))
# train_data_multi = train_data_multi.cache().shuffle(BUFFER_SIZE).batch(BATCH_SIZE).repeat()

# val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))
# val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

print (x_train_multi.shape,
       y_train_multi.shape,
       'Single window of past history : {}'.format(x_train_multi[0].shape),
       'Target temperature to predict : {}'.format(y_train_multi[0].shape),
       sep='\n')
# Out:
# (5963, 20, 3)
# (5963, 5)
# Single window of past history : (20, 3)
# Target temperature to predict : (5,)

# %%
# for x, y in val_data_multi.take(1):
#     multi_step_plot(x[0], y[0], np.array([0]))

# %%
# LSTM Parameters
EVALUATION_INTERVAL = 30 #len(x_train_multi)//batch_size//2 #15
VALIDATION_INTERVAL = 30 #len(x_val_multi)//batch_size//2
EPOCHS = 50
PATIENCE = 5

# Reproducibility
SEED = 42
tf.random.set_seed(SEED)

# %%
multi_step_model = tf.keras.models.Sequential()
multi_step_model.add(tf.keras.layers.LSTM(32,
                                          return_sequences=True,
                                          input_shape=x_train_multi.shape[-2:]))
multi_step_model.add(tf.keras.layers.Dropout(0.4))
multi_step_model.add(Dense(16))

multi_step_model.add(tf.keras.layers.LSTM(16))
multi_step_model.add(tf.keras.layers.Dropout(0.4))
multi_step_model.add(Dense(8))

multi_step_model.add(Dense(future_target,activation='linear'))



multi_step_model.compile(optimizer=tf.keras.optimizers.legacy.Adam(),loss='mae', metrics='accuracy')
print(multi_step_model.summary())
# Out:
# Model: "sequential_13"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_26 (LSTM)              (None, 20, 32)            4608
#
#  dropout_26 (Dropout)        (None, 20, 32)            0
#
#  dense_39 (Dense)            (None, 20, 16)            528
#
#  lstm_27 (LSTM)              (None, 16)                2112
#
#  dropout_27 (Dropout)        (None, 16)                0
#
#  dense_40 (Dense)            (None, 8)                 136
#
#  dense_41 (Dense)            (None, 5)                 45
#
# =================================================================
# Total params: 7429 (29.02 KB)
# Trainable params: 7429 (29.02 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience = 10, restore_best_weights=True)
multi_step_history = multi_step_model.fit(x_train_multi,y_train_multi,
                                          epochs=EPOCHS,
                                          steps_per_epoch=EVALUATION_INTERVAL,
                                          validation_data=(x_val_multi,y_val_multi),
                                          validation_steps=VALIDATION_INTERVAL,
                                          callbacks=[early_stopping])
# Out:
# Epoch 1/50
# 2023-10-06 21:55:49.740153: I tensorflow/core/data/root_dataset.cc:62] `tf.data.Options` values set are distribute_options {
#   auto_shard_policy: DATA
# }
# optimization_options {
#   apply_default_optimizations: false
# }
# threading_options {
# }
# external_state_policy: POLICY_IGNORE
# autotune_options {
# }
# warm_start: false
# 30/30 [==============================] - ETA: 0s - loss: 0.6938 - accuracy: 0.1979
# 2023-10-06 21:56:09.745487: I tensorflow/core/data/root_dataset.cc:62] `tf.data.Options` values set are distribute_options {
#   auto_shard_policy: DATA
# }
# optimization_options {
#   apply_default_optimizations: false
# }
# threading_options {
# }
# autotune_options {
# }
# warm_start: false
# 30/30 [==============================] - 22s 162ms/step - loss: 0.6938 - accuracy: 0.1979 - val_loss: 0.3191 - val_accuracy: 0.1842
# Epoch 2/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.3742 - accuracy: 0.1954 - val_loss: 0.1706 - val_accuracy: 0.1849
# Epoch 3/50
# 30/30 [==============================] - 2s 75ms/step - loss: 0.2824 - accuracy: 0.1883 - val_loss: 0.1215 - val_accuracy: 0.1992
# Epoch 4/50
# 30/30 [==============================] - 3s 94ms/step - loss: 0.2488 - accuracy: 0.2002 - val_loss: 0.1084 - val_accuracy: 0.1815
# Epoch 5/50
# 30/30 [==============================] - 2s 82ms/step - loss: 0.2302 - accuracy: 0.1994 - val_loss: 0.1047 - val_accuracy: 0.2019
# Epoch 6/50
# 30/30 [==============================] - 2s 76ms/step - loss: 0.2144 - accuracy: 0.1939 - val_loss: 0.0999 - val_accuracy: 0.2101
# Epoch 7/50
# 30/30 [==============================] - 2s 64ms/step - loss: 0.2024 - accuracy: 0.2006 - val_loss: 0.0975 - val_accuracy: 0.1910
# Epoch 8/50
# 30/30 [==============================] - 4s 119ms/step - loss: 0.1971 - accuracy: 0.2048 - val_loss: 0.0834 - val_accuracy: 0.1978
# Epoch 9/50
# 30/30 [==============================] - 3s 109ms/step - loss: 0.1905 - accuracy: 0.2033 - val_loss: 0.0845 - val_accuracy: 0.2101
# Epoch 10/50
# 30/30 [==============================] - 2s 82ms/step - loss: 0.1895 - accuracy: 0.1910 - val_loss: 0.0898 - val_accuracy: 0.1856
# Epoch 11/50
# 30/30 [==============================] - 2s 77ms/step - loss: 0.1849 - accuracy: 0.1913 - val_loss: 0.0844 - val_accuracy: 0.2005
# Epoch 12/50
# 30/30 [==============================] - 2s 73ms/step - loss: 0.1820 - accuracy: 0.1967 - val_loss: 0.0799 - val_accuracy: 0.1842
# Epoch 13/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.1801 - accuracy: 0.1947 - val_loss: 0.0813 - val_accuracy: 0.2407
# Epoch 14/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.1759 - accuracy: 0.1955 - val_loss: 0.0840 - val_accuracy: 0.2114
# Epoch 15/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.1757 - accuracy: 0.1917 - val_loss: 0.0793 - val_accuracy: 0.1985
# Epoch 16/50
# 30/30 [==============================] - 2s 72ms/step - loss: 0.1726 - accuracy: 0.1969 - val_loss: 0.0810 - val_accuracy: 0.2196
# Epoch 17/50
# 30/30 [==============================] - 2s 73ms/step - loss: 0.1697 - accuracy: 0.2009 - val_loss: 0.0741 - val_accuracy: 0.2094
# Epoch 18/50
# 30/30 [==============================] - 2s 66ms/step - loss: 0.1710 - accuracy: 0.1935 - val_loss: 0.0771 - val_accuracy: 0.1917
# Epoch 19/50
# 30/30 [==============================] - 2s 72ms/step - loss: 0.1685 - accuracy: 0.2012 - val_loss: 0.0766 - val_accuracy: 0.1856
# Epoch 20/50
# 30/30 [==============================] - 2s 69ms/step - loss: 0.1670 - accuracy: 0.1942 - val_loss: 0.0785 - val_accuracy: 0.1693
# Epoch 21/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.1686 - accuracy: 0.2063 - val_loss: 0.0748 - val_accuracy: 0.2101
# Epoch 22/50
# 30/30 [==============================] - 2s 65ms/step - loss: 0.1705 - accuracy: 0.1957 - val_loss: 0.0830 - val_accuracy: 0.2400
# Epoch 23/50
# 30/30 [==============================] - 2s 60ms/step - loss: 0.1643 - accuracy: 0.1910 - val_loss: 0.0802 - val_accuracy: 0.1795
# Epoch 24/50
# 30/30 [==============================] - 2s 59ms/step - loss: 0.1631 - accuracy: 0.2019 - val_loss: 0.0763 - val_accuracy: 0.1897
# Epoch 25/50
# 30/30 [==============================] - 2s 76ms/step - loss: 0.1671 - accuracy: 0.1974 - val_loss: 0.0719 - val_accuracy: 0.2305
# Epoch 26/50
# 30/30 [==============================] - 3s 85ms/step - loss: 0.1683 - accuracy: 0.1967 - val_loss: 0.0776 - val_accuracy: 0.2413
# Epoch 27/50
# 30/30 [==============================] - 4s 135ms/step - loss: 0.1621 - accuracy: 0.1967 - val_loss: 0.0787 - val_accuracy: 0.2073
# Epoch 28/50
# 30/30 [==============================] - 4s 137ms/step - loss: 0.1642 - accuracy: 0.1930 - val_loss: 0.0792 - val_accuracy: 0.2257
# Epoch 29/50
# 30/30 [==============================] - 5s 154ms/step - loss: 0.1616 - accuracy: 0.2014 - val_loss: 0.0772 - val_accuracy: 0.1835
# Epoch 30/50
# 30/30 [==============================] - 4s 133ms/step - loss: 0.1659 - accuracy: 0.1962 - val_loss: 0.0739 - val_accuracy: 0.2488
# Epoch 31/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.1654 - accuracy: 0.2048 - val_loss: 0.0722 - val_accuracy: 0.2318
# Epoch 32/50
# 30/30 [==============================] - 2s 67ms/step - loss: 0.1637 - accuracy: 0.1937 - val_loss: 0.0741 - val_accuracy: 0.1625
# Epoch 33/50
# 30/30 [==============================] - 2s 63ms/step - loss: 0.1631 - accuracy: 0.1902 - val_loss: 0.0803 - val_accuracy: 0.1672
# Epoch 34/50
# 30/30 [==============================] - 2s 79ms/step - loss: 0.1649 - accuracy: 0.2083 - val_loss: 0.0678 - val_accuracy: 0.1937
# Epoch 35/50
# 30/30 [==============================] - 3s 94ms/step - loss: 0.1609 - accuracy: 0.1960 - val_loss: 0.0723 - val_accuracy: 0.1924
# Epoch 36/50
# 30/30 [==============================] - 2s 73ms/step - loss: 0.1625 - accuracy: 0.1999 - val_loss: 0.0724 - val_accuracy: 0.2536
# Epoch 37/50
# 30/30 [==============================] - 2s 58ms/step - loss: 0.1618 - accuracy: 0.2024 - val_loss: 0.0826 - val_accuracy: 0.2237
# Epoch 38/50
# 30/30 [==============================] - 2s 70ms/step - loss: 0.1656 - accuracy: 0.2036 - val_loss: 0.0797 - val_accuracy: 0.2685
# Epoch 39/50
# 30/30 [==============================] - 2s 75ms/step - loss: 0.1612 - accuracy: 0.1910 - val_loss: 0.0684 - val_accuracy: 0.1856
# Epoch 40/50
# 30/30 [==============================] - 3s 88ms/step - loss: 0.1631 - accuracy: 0.1930 - val_loss: 0.0811 - val_accuracy: 0.1523
# Epoch 41/50
# 30/30 [==============================] - 4s 121ms/step - loss: 0.1568 - accuracy: 0.1952 - val_loss: 0.0674 - val_accuracy: 0.2237
# Epoch 42/50
# 30/30 [==============================] - 2s 82ms/step - loss: 0.1598 - accuracy: 0.1813 - val_loss: 0.0774 - val_accuracy: 0.1557
# Epoch 43/50
# 30/30 [==============================] - 3s 90ms/step - loss: 0.1619 - accuracy: 0.1969 - val_loss: 0.0709 - val_accuracy: 0.2087
# Epoch 44/50
# 30/30 [==============================] - 3s 84ms/step - loss: 0.1603 - accuracy: 0.2019 - val_loss: 0.0680 - val_accuracy: 0.2379
# Epoch 45/50
# 30/30 [==============================] - 3s 88ms/step - loss: 0.1595 - accuracy: 0.2001 - val_loss: 0.0691 - val_accuracy: 0.1924
# Epoch 46/50
# 30/30 [==============================] - 5s 156ms/step - loss: 0.1634 - accuracy: 0.2073 - val_loss: 0.0756 - val_accuracy: 0.2665
# Epoch 47/50
# 30/30 [==============================] - 3s 108ms/step - loss: 0.1620 - accuracy: 0.2120 - val_loss: 0.0716 - val_accuracy: 0.2590
# Epoch 48/50
# 30/30 [==============================] - 3s 95ms/step - loss: 0.1613 - accuracy: 0.2093 - val_loss: 0.0824 - val_accuracy: 0.2644
# Epoch 49/50
# 30/30 [==============================] - 3s 90ms/step - loss: 0.1607 - accuracy: 0.1967 - val_loss: 0.0725 - val_accuracy: 0.2277
# Epoch 50/50
# 30/30 [==============================] - 2s 79ms/step - loss: 0.1618 - accuracy: 0.1991 - val_loss: 0.0688 - val_accuracy: 0.1917

# %%
# plot_train_history(multi_step_history, 'Multi-Step Training and validation loss')

# %%
history_df = pd.DataFrame(multi_step_history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['accuracy', 'val_accuracy']].plot(title="Accuracy")
# Out:
# <Axes: title={'center': 'Accuracy'}>

# %%
x_val_multi, y_val_multi = multivariate_data(dataset, dataset[:, 0],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

x_val_multi = x_val_multi[-20:]
y_val_multi = y_val_multi[-20:]

val_data_multi = tf.data.Dataset.from_tensor_slices((x_val_multi, y_val_multi))

val_data_multi = val_data_multi.batch(BATCH_SIZE).repeat()

for x, y in val_data_multi.take(1):
    multi_step_plot(x[0], y[0], multi_step_model.predict(x)[0])
# Out:
# 2023-10-06 21:58:17.596425: I tensorflow/core/data/root_dataset.cc:62] `tf.data.Options` values set are
# 2023-10-06 21:58:17.698511: I tensorflow/core/data/root_dataset.cc:62] `tf.data.Options` values set are distribute_options {
#   auto_shard_policy: DATA
# }
# optimization_options {
#   apply_default_optimizations: false
# }
# threading_options {
# }
# autotune_options {
# }
# warm_start: false
# 1/1 [==============================] - 2s 2s/step

# %%
x_new_multi = multinew_data(dataset, dataset[:, 0],
                                             TRAIN_SPLIT, None, past_history,
                                             future_target, STEP)

x_new_multi = x_new_multi[-20:]



predictions_0 = multi_step_model.predict(x_new_multi[0:1])
predictions_1 = multi_step_model.predict(x_new_multi[-1:])#[0]


predictions_0, predictions_1
# np.shape(x_new_multi)
# x_new_multi[0:1],x_new_multi[-1:]
# Out:
# 2023-10-06 21:58:20.821942: I tensorflow/core/data/root_dataset.cc:62] `tf.data.Options` values set are distribute_options {
#   auto_shard_policy: DATA
# }
# optimization_options {
#   apply_default_optimizations: false
# }
# threading_options {
# }
# autotune_options {
# }
# warm_start: false
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 0s 32ms/step
# 2023-10-06 21:58:22.168249: I tensorflow/core/data/root_dataset.cc:62] `tf.data.Options` values set are distribute_options {
#   auto_shard_policy: DATA
# }
# optimization_options {
#   apply_default_optimizations: false
# }
# threading_options {
# }
# autotune_options {
# }
# warm_start: false
# (array([[0.6044753 , 0.60407406, 0.60599935, 0.6100508 , 0.6091953 ]],
#        dtype=float32),
#  array([[0.6430624 , 0.6424927 , 0.6445458 , 0.64859664, 0.64799374]],
#        dtype=float32))

# %%
# New Predictions
prediction_plot(x_new_multi[0][:,0], predictions_0)
prediction_plot(x_new_multi[-1][:,0], predictions_1)

# %%
#  multi_step_model.save(f"model/model_{ticker}.h5")
